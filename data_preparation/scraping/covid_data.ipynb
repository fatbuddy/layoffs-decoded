# %%
import pandas as pd

# %%
import requests

url = "https://covid.ourworldindata.org/data/owid-covid-data.csv"
response = requests.get(url)

with open("owid-covid-data.csv", "wb") as f:
    f.write(response.content)

# %%
covid_df = pd.read_csv('owid-covid-data.csv')

# %%
covid_df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0           NaN                  37.746                         0.5
# 1           NaN                  37.746                         0.5
# 2           NaN                  37.746                         0.5
# 3           NaN                  37.746                         0.5
# 4           NaN                  37.746                         0.5
#
#    life_expectancy  human_development_index  population  \
# 0            64.83                    0.511  41128772.0
# 1            64.83                    0.511  41128772.0
# 2            64.83                    0.511  41128772.0
# 3            64.83                    0.511  41128772.0
# 4            64.83                    0.511  41128772.0
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
#Filter the data for only United States
US_covid_df = covid_df[covid_df['location']=='United States']

# %%
US_covid_df.head()
# Out:
#        iso_code      continent       location        date  total_cases  \
# 276106      USA  North America  United States  2020-01-03          NaN
# 276107      USA  North America  United States  2020-01-04          NaN
# 276108      USA  North America  United States  2020-01-05          NaN
# 276109      USA  North America  United States  2020-01-06          NaN
# 276110      USA  North America  United States  2020-01-07          NaN
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 276106        0.0                 NaN           NaN         0.0
# 276107        0.0                 NaN           NaN         0.0
# 276108        0.0                 NaN           NaN         0.0
# 276109        0.0                 NaN           NaN         0.0
# 276110        0.0                 NaN           NaN         0.0
#
#         new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# 276106                  NaN  ...          24.6                     NaN
# 276107                  NaN  ...          24.6                     NaN
# 276108                  NaN  ...          24.6                     NaN
# 276109                  NaN  ...          24.6                     NaN
# 276110                  NaN  ...          24.6                     NaN
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 276106                        2.77            78.86                    0.926
# 276107                        2.77            78.86                    0.926
# 276108                        2.77            78.86                    0.926
# 276109                        2.77            78.86                    0.926
# 276110                        2.77            78.86                    0.926
#
#          population  excess_mortality_cumulative_absolute  \
# 276106  338289856.0                                   NaN
# 276107  338289856.0                                   NaN
# 276108  338289856.0                               -2634.0
# 276109  338289856.0                                   NaN
# 276110  338289856.0                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 276106                          NaN               NaN
# 276107                          NaN               NaN
# 276108                        -4.19             -4.19
# 276109                          NaN               NaN
# 276110                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 276106                                      NaN
# 276107                                      NaN
# 276108                                -7.840639
# 276109                                      NaN
# 276110                                      NaN
#
# [5 rows x 67 columns]

# %%
US_covid_df = US_covid_df.dropna(subset=["total_cases"])

# %%
US_covid_df
# Out:
#        iso_code      continent       location        date  total_cases  \
# 276123      USA  North America  United States  2020-01-20          1.0
# 276124      USA  North America  United States  2020-01-21          1.0
# 276125      USA  North America  United States  2020-01-22          1.0
# 276126      USA  North America  United States  2020-01-23          1.0
# 276127      USA  North America  United States  2020-01-24          1.0
# ...         ...            ...            ...         ...          ...
# 277261      USA  North America  United States  2023-03-03  102019564.0
# 277262      USA  North America  United States  2023-03-04  102247392.0
# 277263      USA  North America  United States  2023-03-05  102247392.0
# 277264      USA  North America  United States  2023-03-06  102247392.0
# 277265      USA  North America  United States  2023-03-07  102247392.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 276123        1.0               0.143           NaN         0.0
# 276124        0.0               0.143           NaN         0.0
# 276125        0.0               0.143           NaN         0.0
# 276126        0.0               0.143           NaN         0.0
# 276127        0.0               0.143           NaN         0.0
# ...           ...                 ...           ...         ...
# 277261        0.0           38166.857     1109145.0         0.0
# 277262   227828.0           32546.857     1111342.0      2197.0
# 277263        NaN                 NaN     1111342.0         NaN
# 277264        NaN                 NaN     1111342.0         NaN
# 277265        NaN                 NaN     1111342.0         NaN
#
#         new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# 276123                0.000  ...          24.6                     NaN
# 276124                0.000  ...          24.6                     NaN
# 276125                0.000  ...          24.6                     NaN
# 276126                0.000  ...          24.6                     NaN
# 276127                0.000  ...          24.6                     NaN
# ...                     ...  ...           ...                     ...
# 277261              337.429  ...          24.6                     NaN
# 277262              313.857  ...          24.6                     NaN
# 277263                  NaN  ...          24.6                     NaN
# 277264                  NaN  ...          24.6                     NaN
# 277265                  NaN  ...          24.6                     NaN
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 276123                        2.77            78.86                    0.926
# 276124                        2.77            78.86                    0.926
# 276125                        2.77            78.86                    0.926
# 276126                        2.77            78.86                    0.926
# 276127                        2.77            78.86                    0.926
# ...                            ...              ...                      ...
# 277261                        2.77            78.86                    0.926
# 277262                        2.77            78.86                    0.926
# 277263                        2.77            78.86                    0.926
# 277264                        2.77            78.86                    0.926
# 277265                        2.77            78.86                    0.926
#
#          population  excess_mortality_cumulative_absolute  \
# 276123  338289856.0                                   NaN
# 276124  338289856.0                                   NaN
# 276125  338289856.0                                   NaN
# 276126  338289856.0                                   NaN
# 276127  338289856.0                                   NaN
# ...             ...                                   ...
# 277261  338289856.0                                   NaN
# 277262  338289856.0                                   NaN
# 277263  338289856.0                                   NaN
# 277264  338289856.0                                   NaN
# 277265  338289856.0                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 276123                          NaN               NaN
# 276124                          NaN               NaN
# 276125                          NaN               NaN
# 276126                          NaN               NaN
# 276127                          NaN               NaN
# ...                             ...               ...
# 277261                          NaN               NaN
# 277262                          NaN               NaN
# 277263                          NaN               NaN
# 277264                          NaN               NaN
# 277265                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 276123                                      NaN
# 276124                                      NaN
# 276125                                      NaN
# 276126                                      NaN
# 276127                                      NaN
# ...                                         ...
# 277261                                      NaN
# 277262                                      NaN
# 277263                                      NaN
# 277264                                      NaN
# 277265                                      NaN
#
# [1143 rows x 67 columns]
